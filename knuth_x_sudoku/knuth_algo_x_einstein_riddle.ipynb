# %%
import pandas as pd
import yaml

# %%
class node:

    def __init__(self):
        self.up = self
        self.down = self
        self.left = self
        self.right = self
        self.COL = None
        self.ROW = None

    def hideInCol(self):
        self.up.down = self.down
        self.down.up = self.up
        self.COL.row_count -= 1
        return self

    def showInCol(self):
        self.up.down = self
        self.down.up = self
        self.COL.row_count += 1
        return self

    def hideInRow(self):
        self.left.right = self.right
        self.right.left = self.left
        return self

    def showInRow(self):
        self.left.right = self
        self.right.left = self
        return self
    
    def deleteUnuseableRow(self):
        cur_cell = self.right 
        while cur_cell != self:
            print(cur_cell.COL.label)
            cur_cell.hideInCol()
            cur_cell = cur_cell.right
        print("done")
        self.hideInCol()
        return

    def hideWholeRow(self, start = None):
        if start == None: # if we just started the loop, don't hide me from my column, but go to my neighbor
            self.right.hideWholeRow(start = self)
            return
        if start != self: # we are not first and not last => hide me and continue
            self.hideInCol()
            self.right.hideWholeRow(start = start)
            return
        return # last possibility start == self => we have looped and can finish

    def showWholeRow(self, start = None):
        if start == None: # if we just started the loop, don't hide me from my column, but go to my neighbor
            self.left.showWholeRow(start = self)
            return
        if start != self: # we are not first and not last => hide me and continue
            self.showInCol()
            self.left.showWholeRow(start = start)
            return
        return # last possibility start == self => we have looped and can finish
    
    def getNeighbor(self, direction, by=0):
        neighbor = {
            'left'  : self.left,
            'right' : self.right,
            'up'    : self.up,
            'down'  : self.down
        }[direction]
        if by > 0:
            return neighbor.getNeighbor(direction, by = by-1)
        return neighbor

# %%
class columnHeader(node):

    def __init__(self, label):
        super().__init__()
        self.label = label
        self.row_count = 0
        self.COL = self

    def hideMe(self):
        self.hideInRow()
        cell = self.down
        while cell != self:
            cell.hideWholeRow()
            cell = cell.down
        return self

    def showMe(self):
        self.showInRow()
        cell = self.up
        while cell != self:
            cell.showWholeRow()
            cell = cell.up
        return self

    def appendRow(self, row):
        row.down = self
        row.up = self.up
        self.up.down = row
        self.up = row
        row.COL = self
        self.row_count += 1
        return self

    def addToRoot(self, root):
        root.appendColumn(self)
        return self

# %%
class rowHeader(node):
    
    def __init__(self, label):
        super().__init__()
        self.label = label
        self.ROW = self

    def appendColumn(self, col):
        col.right = self
        col.left = self.left
        self.left.right = col
        self.left = col
        col.ROW = self
        return self

    def addToRoot(self, root):
        root.appendRow(self)
        return self

# %%
class rootNode(columnHeader, rowHeader):

    def __init__(self):
        node.__init__(self)
        self.row_count = 0
        self.label = None
        self.ROW = self
        self.COL = self

    def addToRoot(self, root):
        pass

# %%
def append_dict(d, e):
    r = d.copy()
    r.update(e)
    return r

# %%
class einstein_matrix:
    
    def __init__(self, attributes):
        self.matrix_root = rootNode()

        self.column_headers = {
            atr_name : {
                atr_val : columnHeader(f"{atr_name} : {atr_val}").addToRoot(self.matrix_root)
                for atr_val in attributes[atr_name]
            }
            for atr_name in attributes
        }

        attr_names = list(attributes.keys())
        deg = len(attr_names)

        row_labels = [{}]
        for attr_name in attr_names:
            row_labels = [ append_dict(l, {attr_name : d_val})  for l in row_labels for d_val in attributes[attr_name]]

        self.row_headers = []

        # construct the sparse matrix

        for row_label in row_labels:

            row_header = rowHeader(row_label)
            self.matrix_root.appendRow(row_header)
        
            for attr_name in row_label:
                
                attr_val = row_label[attr_name]
                cell = node()
                row_header.appendColumn(cell)
                column_header = self.column_headers[attr_name][attr_val]
                column_header.appendRow(cell)

            self.row_headers.append(row_header)

    def remove_unusable_entires(self, facts):

        for fact in facts:
            
            (k1 , v1), (k2, v2) = fact.items()
            print(k1, v1, k2, v2)
            current_row = self.matrix_root.down

            while (current_row != self.matrix_root):
                label = current_row.label
                if (
                    label[k1] == v1 and label[k2] != v2 \
                    or label[k1] != v1 and label[k2] == v2 \
                ):
                    print(label)
                    current_row.deleteUnuseableRow()
                current_row = current_row.down

# %%
def search(matrix, solution=[], log=[], k=0):

    # print(f"k : {k}")

    if type(matrix) != rootNode:
        raise TypeError("Must start with matrix root node")

    # solution found if matrix is empty
    if matrix.right == matrix:
        print("ready")
        return prep_solution(solution)

    # select column
    col = matrix.right
    tmp_col = col
    while tmp_col != matrix:
        if tmp_col.row_count < col.row_count:
            col = tmp_col
        tmp_col = tmp_col.right
    print(col.label)
    # hide column 
    col.hideMe()
    # go through its each row
    row = col.down
    print(row.ROW.label)
    while row != col:
        # add row to solution
        solution.append(row)
        log.append(f"select R{row.ROW.label['R']}C{row.ROW.label['C']}={row.ROW.label['#']}")
        # hide row's columns
        cell = row.right
        while cell != row:
            if type(cell) != rowHeader:
                cell.COL.hideMe()
            cell = cell.right
        # go deeper
        result = search(matrix, solution, log, k = k+1)
        if result != None:
            return result
        # uncover columns and remove row from solution
        solution.pop()
        log.append("back")
        cell = row.left
        while cell != row:
            if type(cell) != rowHeader:
                cell.COL.showMe()
            cell = cell.left
        # next row
        row = row.down
    # # uncover column
    col.showMe()
    return None

# %%
filename = 'input_1_einstein.yml'

# %%
with open(filename, 'r') as f:
    riddle_text = yaml.safe_load(f)

# %%
m = einstein_matrix(riddle_text['attributes'])

# %%
m.remove_unusable_entires(riddle_text['facts'])
# Out:
# nationality Englishman color red
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : coffee
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : tea
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : milk
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : orange juice
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Spaniard
# drink : water
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : coffee
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : horse
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : zebra
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : milk
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : dog
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : dog
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : dog
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : dog
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : snails
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : snails
# cigarettes : Chesterfields
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Lucky Strike'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : snails
# cigarettes : Lucky Strike
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'snails', 'cigarettes': 'Parliaments'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : snails
# cigarettes : Parliaments
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Old Gold'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : fox
# cigarettes : Old Gold
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 1, 'color': 'red', 'nationality': 'Ukrainian', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 1
# color : red
# nationality : Ukrainian
# drink : orange juice
# pet : fox
# cigarettes : Chesterfields
# done
# ...
# color : blue
# nationality : Japanese
# drink : milk
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 3, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'milk', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 3
# color : blue
# nationality : Japanese
# drink : milk
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 3, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'milk', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 3
# color : blue
# nationality : Japanese
# drink : milk
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 3, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'milk', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 3
# color : blue
# nationality : Japanese
# drink : milk
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'red', 'nationality': 'Englishman', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : red
# nationality : Englishman
# drink : water
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'red', 'nationality': 'Englishman', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : red
# nationality : Englishman
# drink : water
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'red', 'nationality': 'Englishman', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : red
# nationality : Englishman
# drink : water
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'green', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : green
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 4
# color : green
# nationality : Japanese
# drink : coffee
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 4, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : green
# nationality : Japanese
# drink : coffee
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : green
# nationality : Japanese
# drink : coffee
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : green
# nationality : Japanese
# drink : coffee
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : ivory
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : ivory
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : ivory
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : ivory
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : orange juice
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : orange juice
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : orange juice
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : water
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : water
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : water
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : ivory
# nationality : Japanese
# drink : water
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'yellow', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 4
# color : yellow
# nationality : Japanese
# drink : water
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 4, 'color': 'yellow', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 4
# color : yellow
# nationality : Japanese
# drink : water
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 4, 'color': 'yellow', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 4
# color : yellow
# nationality : Japanese
# drink : water
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : blue
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : blue
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : blue
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 4
# color : blue
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : orange juice
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : orange juice
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : orange juice
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : water
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : water
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : water
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 4, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 4
# color : blue
# nationality : Japanese
# drink : water
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'red', 'nationality': 'Englishman', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : red
# nationality : Englishman
# drink : water
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'red', 'nationality': 'Englishman', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : red
# nationality : Englishman
# drink : water
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'red', 'nationality': 'Englishman', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : red
# nationality : Englishman
# drink : water
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'green', 'nationality': 'Spaniard', 'drink': 'coffee', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : green
# nationality : Spaniard
# drink : coffee
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 5
# color : green
# nationality : Japanese
# drink : coffee
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 5, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : green
# nationality : Japanese
# drink : coffee
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : green
# nationality : Japanese
# drink : coffee
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'green', 'nationality': 'Japanese', 'drink': 'coffee', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : green
# nationality : Japanese
# drink : coffee
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : ivory
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : ivory
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : ivory
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : ivory
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : orange juice
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : orange juice
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : orange juice
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : water
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : water
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : water
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'ivory', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : ivory
# nationality : Japanese
# drink : water
# pet : zebra
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'yellow', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Kools'}
# house_no : 5
# color : yellow
# nationality : Japanese
# drink : water
# pet : fox
# cigarettes : Kools
# done
# {'house_no': 5, 'color': 'yellow', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Kools'}
# house_no : 5
# color : yellow
# nationality : Japanese
# drink : water
# pet : horse
# cigarettes : Kools
# done
# {'house_no': 5, 'color': 'yellow', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Kools'}
# house_no : 5
# color : yellow
# nationality : Japanese
# drink : water
# pet : zebra
# cigarettes : Kools
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Spaniard', 'drink': 'water', 'pet': 'dog', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : blue
# nationality : Spaniard
# drink : water
# pet : dog
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'fox', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : blue
# nationality : Ukrainian
# drink : tea
# pet : fox
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'horse', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : blue
# nationality : Ukrainian
# drink : tea
# pet : horse
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Ukrainian', 'drink': 'tea', 'pet': 'zebra', 'cigarettes': 'Parliaments'}
# house_no : 5
# color : blue
# nationality : Ukrainian
# drink : tea
# pet : zebra
# cigarettes : Parliaments
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'fox', 'cigarettes': 'Lucky Strike'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : orange juice
# pet : fox
# cigarettes : Lucky Strike
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'horse', 'cigarettes': 'Lucky Strike'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : orange juice
# pet : horse
# cigarettes : Lucky Strike
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'orange juice', 'pet': 'zebra', 'cigarettes': 'Lucky Strike'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : orange juice
# pet : zebra
# cigarettes : Lucky Strike
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'snails', 'cigarettes': 'Old Gold'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : water
# pet : snails
# cigarettes : Old Gold
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'fox', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : water
# pet : fox
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'horse', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : water
# pet : horse
# cigarettes : Chesterfields
# done
# {'house_no': 5, 'color': 'blue', 'nationality': 'Japanese', 'drink': 'water', 'pet': 'zebra', 'cigarettes': 'Chesterfields'}
# house_no : 5
# color : blue
# nationality : Japanese
# drink : water
# pet : zebra
# cigarettes : Chesterfields
# done

# %%
r = m.matrix_root
s = r.right
while (s != r):
    if s.row_count <1 :
        print(s.label)
    s = s.right
